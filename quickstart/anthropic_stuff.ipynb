# %%
import anthropic
import os 
from dotenv import load_dotenv
load_dotenv()

client = anthropic.Anthropic(
    # defaults to os.environ.get("ANTHROPIC_API_KEY")
    api_key=os.getenv("ANTHROPIC_API_KEY"),
)
message = client.messages.create(
    model="claude-3-opus-20240229",
    max_tokens=1000,
    temperature=0,
    system="You are a helpful assistant that is an expert at writing Python scripts",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Whats a good script that I can use to automate my daily tasks?"
                }
            ]
        }
    ]
)
response = message.content[0].text

print(response)
# Out:
# The specific script you can use to automate your daily tasks depends on the nature of those tasks. However, I can provide you with a general example of a Python script that demonstrates how you can automate various tasks using different libraries and functionalities. Here's an example:
#
# ```python
# import os
# import subprocess
# import requests
# import smtplib
# from email.mime.text import MIMEText
# from email.mime.multipart import MIMEMultipart
# from datetime import datetime
#
# def run_system_command(command):
#     try:
#         subprocess.run(command, shell=True, check=True)
#         print(f"Command executed successfully: {command}")
#     except subprocess.CalledProcessError as e:
#         print(f"Error executing command: {command}")
#         print(f"Error message: {str(e)}")
#
# def send_email(subject, body, recipient):
#     sender_email = "your_email@example.com"
#     sender_password = "your_email_password"
#
#     message = MIMEMultipart()
#     message["From"] = sender_email
#     message["To"] = recipient
#     message["Subject"] = subject
#
#     message.attach(MIMEText(body, "plain"))
#
#     try:
#         with smtplib.SMTP("smtp.example.com", 587) as server:
#             server.starttls()
#             server.login(sender_email, sender_password)
#             server.send_message(message)
#         print("Email sent successfully!")
#     except Exception as e:
#         print("Error sending email:")
#         print(str(e))
#
# def main():
#     # Example task 1: Run a system command
#     command = "ls -l"
#     run_system_command(command)
#
#     # Example task 2: Make an API request
#     url = "https://api.example.com/data"
#     try:
#         response = requests.get(url)
#         data = response.json()
#         print("API response:")
#         print(data)
#     except requests.exceptions.RequestException as e:
#         print("Error making API request:")
#         print(str(e))
#
#     # Example task 3: Send an email
#     subject = "Daily Task Report"
#     body = "This is an automated email containing the daily task report."
#     recipient = "recipient@example.com"
#     send_email(subject, body, recipient)
#
#     # Example task 4: Backup files
#     source_directory = "/path/to/source/directory"
#     backup_directory = "/path/to/backup/directory"
#     timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
#     backup_filename = f"backup_{timestamp}.zip"
#     backup_path = os.path.join(backup_directory, backup_filename)
#
#     zip_command = f"zip -r {backup_path} {source_directory}"
#     run_system_command(zip_command)
#
# if __name__ == "__main__":
#     main()
# ```
#
# This script includes several example tasks that you can automate:
#
# 1. Running a system command using `subprocess.run()`.
# 2. Making an API request using the `requests` library.
# 3. Sending an email using the `smtplib` library.
# 4. Backing up files by creating a zip archive using the `zip` command.
#
# You can customize and expand upon this script based on your specific daily tasks. For example, you can add more functions to perform different tasks, schedule the script to run at specific times using a task scheduler or a cron job, and integrate with other APIs or services relevant to your workflow.
#
# Remember to replace the placeholders (e.g., `your_email@example.com`, `your_email_password`, `smtp.example.com`, `https://api.example.com/data`) with your actual email credentials, SMTP server details, and API endpoints.
